# %% [markdown]
# #Part 1 - Representation and Biases
# The Stable Diffusion (Rombach et al. 2021) model is trained on subsets of the LAION-5B (Schuhmann et al. 2022) image dataset. In the current study, we explore the impacts of various descriptor use on the images output by the Stable Diffusion model. Captions are generated using BLIP.

# %%
#Install the libraries for Stable Diffusion
# !pip install -q diffusers transformers git+https://github.com/huggingface/accelerate.git
# !pip install -q opencv-contrib-python
# !pip install -q imutils
# !pip install -q controlnet_aux
# !pip install -q mediapipe

#Install the requirements for BLIP
import sys
if 'google.colab' in sys.modules:
    print('Running in Colab.')
    # !pip3 install transformers==4.15.0 timm==0.4.12
    # !git clone https://github.com/salesforce/BLIP
    # %cd BLIP
# !pip install -q fairscale
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 24.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 31.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 49.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 49.0 MB/s eta 0:00:00
#   Building wheel for accelerate (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.9/261.9 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 36.0 MB/s eta 0:00:00
# Running in Colab.
# Collecting transformers==4.15.0
#   Downloading transformers-4.15.0-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 12.0 MB/s eta 0:00:00
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (2.27.1)
# Collecting sacremoses (from transformers==4.15.0)
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 20.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tokenizers<0.11,>=0.10.1 (from transformers==4.15.0)
#   Downloading tokenizers-0.10.3.tar.gz (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.7/212.7 kB 22.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (4.65.0)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from timm==0.4.12) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.4.12) (0.15.2+cu118)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.15.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.15.0) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.12) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.12) (16.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.15.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.15.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.15.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.15.0) (3.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==4.15.0) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==4.15.0) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==4.15.0) (1.3.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.4.12) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4->timm==0.4.12) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4->timm==0.4.12) (1.3.0)
# Building wheels for collected packages: tokenizers, sacremoses
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for tokenizers (pyproject.toml) ... error
#   ERROR: Failed building wheel for tokenizers
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=0828abc2f4fd5d7e2564a2ff956f80787d0653306ab4e5eae8e0c486ab6d4fe9
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
# Successfully built sacremoses
# Failed to build tokenizers
# ERROR: Could not build wheels for tokenizers, which is required to install pyproject.toml-based projects
# Cloning into 'BLIP'...
# remote: Enumerating objects: 277, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 277 (delta 137), reused 136 (delta 135), pack-reused 112
# Receiving objects: 100% (277/277), 7.03 MiB | 24.67 MiB/s, done.
# Resolving deltas: 100% (153/153), done.
# /content/BLIP
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 2.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for fairscale (pyproject.toml) ... done

# %%
#Load required libraries
import torch
import os
from google.colab import drive

# %%
#Connect to Google Drive
drive.mount('/content/drive/',force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
#Import the stable diffusion pipeline
from diffusers import StableDiffusionPipeline

#device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pipe_sd = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipe_sd = pipe_sd.to("cuda")
# Out:
# Downloading (…)ain/model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Downloading (…)tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading (…)_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# Downloading (…)cheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading (…)_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading (…)7f0/unet/config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# Downloading (…)57f0/vae/config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.

# %%
#Function to generate images using Stable Diffusion
def get_sd(prompt,negative_prompt,num_imgs=10,random_seed=12345):

  plt_imgs = []
  generator = torch.manual_seed(random_seed)

  for i in range(0,num_imgs):
    print("Generating image ", i+1, " of ", num_imgs)
    out_img = pipe_sd(prompt, negative_prompt=neg_prompt, num_inference_steps=20, generator=generator).images[0]
    plt_imgs.append(out_img)

  return plt_imgs

#Function to loop through generation and save images
def gen_imgs(prompt,neg_prompt,results_folder,num_imgs=10):

  #Generate results if they do not yet exist
  if not os.path.isdir("{}/{}".format(results_folder,prompt)):

    #Create the directory
    os.mkdir("{}/{}".format(results_folder,prompt))

    #Generate the images
    print("Generating images for {}".format(prompt))
    images = get_sd(prompt,neg_prompt,num_imgs=num_imgs)

    #Save to the directory
    for i in range(0,len(images),1):
      images[i].save("{}/{}/{}.jpg".format(results_folder,prompt,i))

# %% [markdown]
# #Experiments
#
# We will run a series of experiments to evaluate various descriptors:
#
# ###General Descriptors
#
# **Watercourses:** ditch, canal, brook, creek, stream, river. (6)
#
# **Mood:** tranquil, peaceful, beautiful, moody, raging. (5)
#
# **Locations (Countries)**: Canada, USA, Germany, Scotland, Iceland, Russia, China, India, Brazil, Peru, Argentina, Nigeria, Zimbabwe, South Africa, Australia, New Zealand. (16)
#
# **Locations (Provinces/States)**: Alberta, British Columbia, Ontario, Quebec. Alaska, New York, Florida, Colorado, Montana, Iowa, Kentucky, Washington, Louisiana, California, Maine, North Carolina, Georgia, Texas, Vermont. (20)
#
# **Locations (Famous Rivers)**: Colorado, Hudson, Columbia, Ganges, Danube, Volga, Rhine, Amazon, Mississippi, Mekong, Rio Grande, Nile, Congo, Yangtze, Yellow, Brahmaputra. (16)
#
# ##Morphology Descriptors
#
# **Landscapes:** rural, urban, city, desert, field, grass, swamp, forest, mountain, canyon, valley. (11)
#
# **Gradient:** tidal, flat, calm, pool, riffle, rapids, steep, waterfall. (8)
#
# **Dimensions:** narrow, wide, small, large. (4)
#
# **Geology:** clay, mud, sand, pebble, gravel, cobble, boulders, rock, shale, bedrock, limestone, granite. (12)
#
# ##Environmental Descriptors
#
# **Water Color:** clear, brown, dirty, muddy, murky, tannic, whitewater. (7)
#
# **Flow Condition:** dry, drought, low flow, flowing, high flow, flooding. (6)
#
# **Weather:** sunny, overcast, cloudy, rainy, snowy. (5)
#
# **Season:** spring, summer, fall, autumn, winter. (5)
#
# Total:

# %%
#General descriptors
watercourses = ['ditch','canal','brook','creek','river','stream']

loc_country = ['Canada','USA','Germany','Scotland','Iceland','Russia',
               'China','India','Brazil','Peru','Argentina','Nigeria','Zimbabwe',
               'South Africa','Australia','New Zealand']

loc_state = ['Alberta','British Columbia','Ontario','Quebec','Alaska','New York',
             'Florida','Colorado','Montana','Iowa','Kentucky','Washington','Louisiana','California',
             'Maine','North Carolina','Georgia','Texas','Vermont']

loc_rivers = ['Colorado','Hudson','Columbia','Mississippi','Danube','Rhine','Seine','Thames','Amazon','Rio Negro',
              'Paraguay','Magdalena','Nile','Niger','Zambezi','Congo','Yangtze','Yamuna','Mekong','Ganges',
              'Sepik','Murray','Waikato','Darling']

#Morphological descriptors
morph_land = ['rural','urban','city','desert','field','grass','swamp','forest','mountain','canyon','valley']
morph_grad = ['tidal','flat','calm','pool','riffle','rapids','steep','waterfall']
morph_dim = ['narrow','wide','small','large']
morph_geol = ['clay','mud','sand','pebble','gravel','cobble','boulders','rock','shale','bedrock','limestone','granite']

#Environmental descriptors
env_water = ['clear','brown','blue','dirty','muddy','murky','tannic','whitewater']
env_flow = ['dry','drought','low flow','flowing','high flow','flooding']
env_weather = ['sunny','overcast','cloudy','rainy','snowy']
env_season = ['spring','summer','fall','autumn','winter']

#perfect_prompt = ['sunny summer dry calm small rural mountain rock whitewater river in Maine USA']

# %%
#Run experiments
results_folder = '/content/drive/MyDrive/ControlNet-Experiment/Results2'
neg_prompt = 'grayscale, low quality, painting, people'
num_imgs = 30

for watercourse in watercourses:

  #Generate prompt
  prompt = "{}".format(watercourse)
  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)

for country in loc_country:

  #Generate prompt
  prompt = "river {}".format(country)
  print(prompt)
  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)

for state in loc_state:

  #Generate prompt
  prompt = "river {}".format(state)
  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)

for river in loc_rivers:

  #Generate prompt
  prompt = "{} river".format(river)
  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)

for land in morph_land:

  #Generate prompt
  prompt = "{} river".format(land)
  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)

for grad in morph_grad:

  #Generate prompt
  prompt = "{} river".format(grad)
  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)

for dim in morph_dim:

  #Generate prompt
  prompt = "{} river".format(dim)
  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)

for geol in morph_geol:

  #Generate prompt
  prompt = "{} river".format(geol)
  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)

for water in env_water:

  #Generate prompt
  prompt = "{} river".format(water)
  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)

for flow in env_flow:

  #Generate prompt
  prompt = "{} river".format(flow)
  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)

for weather in env_weather:

  #Generate prompt
  prompt = "{} river".format(weather)
  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)

for season in env_season:

  #Generate prompt
  prompt = "{} river".format(season)
  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)
# Out:
# Generating images for river British Columbia
# Generating image  1  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  2  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  3  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  4  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  5  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  6  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  7  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  8  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  9  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  10  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  11  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  12  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  13  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  14  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  15  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  16  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  17  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  18  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  19  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  20  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  21  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  22  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  23  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  24  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  25  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  26  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  27  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  28  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  29  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# Generating image  30  of  30
#   0%|          | 0/20 [00:00<?, ?it/s]
# '\n\nfor river in loc_rivers:\n\n  #Generate prompt\n  prompt = "{} river".format(river)\n  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)\n\nfor land in morph_land:\n\n  #Generate prompt\n  prompt = "{} river".format(land)\n  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)\n\nfor grad in morph_grad:\n\n  #Generate prompt\n  prompt = "{} river".format(grad)\n  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)\n\nfor dim in morph_dim:\n\n  #Generate prompt\n  prompt = "{} river".format(dim)\n  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)\n\nfor geol in morph_geol:\n\n  #Generate prompt\n  prompt = "{} river".format(geol)\n  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)\n\nfor water in env_water:\n\n  #Generate prompt\n  prompt = "{} river".format(water)\n  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)\n\nfor flow in env_flow:\n\n  #Generate prompt\n  prompt = "{} river".format(flow)\n  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)\n\nfor weather in env_weather:\n\n  #Generate prompt\n  prompt = "{} river".format(weather)\n  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)\n\nfor season in env_season:\n\n  #Generate prompt\n  prompt = "{} river".format(season)\n  gen_imgs(prompt,neg_prompt,results_folder,num_imgs)\n'

# %% [markdown]
# #Part 2 - Caption Analysis
# We will analyze the images generated in Part 1 using the BLIP caption generator. For each category and term the most common words occuring the prompts will be analyzed.

# %%
#Implement BLIP

# install requirements
import sys
if 'google.colab' in sys.modules:
    print('Running in Colab.')
    # !pip3 install transformers==4.15.0 timm==0.4.12
    # !git clone https://github.com/salesforce/BLIP
    # %cd BLIP
# !pip install fairscale
# Out:
# Running in Colab.
# Collecting transformers==4.15.0
#   Using cached transformers-4.15.0-py3-none-any.whl (3.4 MB)
# Collecting timm==0.4.12
#   Using cached timm-0.4.12-py3-none-any.whl (376 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (2.27.1)
# Collecting sacremoses (from transformers==4.15.0)
#   Using cached sacremoses-0.0.53-py3-none-any.whl
# Collecting tokenizers<0.11,>=0.10.1 (from transformers==4.15.0)
#   Using cached tokenizers-0.10.3.tar.gz (212 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.15.0) (4.65.0)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from timm==0.4.12) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.4.12) (0.15.2+cu118)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.15.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.15.0) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.12) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.12) (16.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.15.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.15.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.15.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.15.0) (3.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==4.15.0) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==4.15.0) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==4.15.0) (1.3.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.4.12) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4->timm==0.4.12) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4->timm==0.4.12) (1.3.0)
# Building wheels for collected packages: tokenizers
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for tokenizers (pyproject.toml) ... error
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# ERROR: Could not build wheels for tokenizers, which is required to install pyproject.toml-based projects
# Cloning into 'BLIP'...
# remote: Enumerating objects: 277, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 277 (delta 137), reused 136 (delta 135), pack-reused 112
# Receiving objects: 100% (277/277), 7.03 MiB | 27.08 MiB/s, done.
# Resolving deltas: 100% (152/152), done.
# /content/BLIP/BLIP
# Requirement already satisfied: fairscale in /usr/local/lib/python3.10/dist-packages (0.4.13)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from fairscale) (2.0.1+cu118)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from fairscale) (1.22.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->fairscale) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->fairscale) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->fairscale) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->fairscale) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->fairscale) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->fairscale) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->fairscale) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->fairscale) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->fairscale) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->fairscale) (1.3.0)

# %%
from PIL import Image
import pandas as pd
import numpy as np
import requests
import torch
from torchvision import transforms
from torchvision.transforms.functional import InterpolationMode
from transformers import AutoProcessor, BlipForConditionalGeneration
from collections import Counter

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

processor = AutoProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]

# %%
def get_caption(processor,model,image_loc):
  image = Image.open(image_loc)

  text = ""
  inputs = processor(images=image, text=text, return_tensors="pt")
  outputs = model.generate(**inputs)
  return (processor.decode(outputs[0], skip_special_tokens=True)), outputs

def flatten_list(lst):
    flattened = []
    for item in lst:
        if isinstance(item, list):
            flattened.extend(flatten_list(item))
        else:
            flattened.append(item)
    return flattened

def get_words(processor,outputs):

  words=[]
  for i in range(0,len(outputs)):
    words.append((processor.decode(outputs[i][0],skip_special_tokens=True)).split())
  print(words)

  return(Counter(flatten_list(words)))

# %%
#We will save the captions into a table and then a csv

#Category, caption, term 1, count 1, term 2, count 2, ... term n, count n

# %%
'''
def get_blip(model, preprocess, results_folder, prompt, num_imgs=30):

  outputs = []

  for i in range(0,num_imgs):

    image_loc = "{}/{}/{}.jpg".format(results_folder,prompt,i)
    caption, output = get_caption(processor, model, image_loc)
    print(i," ",caption)
    outputs.append(output)

  word_list = get_words(processor,outputs)
  print(word_list)
  return word_list
  '''

# %%
results_folder = '/content/drive/MyDrive/ControlNet-Experiment/Results2'
#See if results already exist in file
df_file ="{}/captions.csv".format(results_folder)
data = pd.read_csv(df_file)
print(data.dtypes)
# Out:
# Unnamed: 0     int64
# prompt        object
# i              int64
# caption       object
# file          object
# dtype: object

# %%
#Function to get all captions for a prompt and save to csv file
def get_blip(model, preprocess, results_folder, prompt, num_imgs=30):

  outputs = pd.DataFrame(index=np.arange(0, num_imgs), columns=('prompt','i','caption','file'))

  #Load already completed files
  df_file ="{}/captions.csv".format(results_folder)
  data = pd.read_csv(df_file)

  for i in range(0,num_imgs):

    image_loc = "{}/{}/{}.jpg".format(results_folder,prompt,i)

    #if results already exist skip the file
    if data['file'].str.contains(image_loc).any():
      print("Caption already exists for ",prompt,i)
    else:
      caption, output = get_caption(processor, model, image_loc)
      print(i," ",caption)
      outputs.loc[i] = [prompt,i,caption,image_loc]

  #Save to csv
  print("Updating captions.csv file")
  output_path = "{}/captions.csv".format(results_folder)
  outputs.to_csv(output_path, mode='a', header=not os.path.exists(output_path))

  return outputs

# %%
word_lists = []
results_folder = '/content/drive/MyDrive/ControlNet-Experiment/Results2'

for watercourse in watercourses:

  #Generate prompt
  prompt = "{}".format(watercourse)
  print(prompt)
  word_lists.append(get_blip(model, processor, results_folder,prompt))

for country in loc_country:

  #Generate prompt
  prompt = "river {}".format(country)
  print(prompt)
  word_lists.append(get_blip(model, processor, results_folder,prompt))

for state in loc_state:

  #Generate prompt
  prompt = "river {}".format(state)
  print(prompt)
  word_lists.append(get_blip(model, processor, results_folder,prompt))

for river in loc_rivers:

  #Generate prompt
  prompt = "{} river".format(river)
  print(prompt)
  word_lists.append(get_blip(model, processor, results_folder,prompt))

for land in morph_land:

  #Generate prompt
  prompt = "{} river".format(land)
  print(prompt)
  word_lists.append(get_blip(model, processor, results_folder,prompt))

for grad in morph_grad:

  #Generate prompt
  prompt = "{} river".format(grad)
  print(prompt)
  word_lists.append(get_blip(model, processor, results_folder,prompt))

for dim in morph_dim:

  #Generate prompt
  prompt = "{} river".format(dim)
  print(prompt)
  word_lists.append(get_blip(model, processor, results_folder,prompt))

for geol in morph_geol:

  #Generate prompt
  prompt = "{} river".format(geol)
  print(prompt)
  word_lists.append(get_blip(model, processor, results_folder,prompt))

for water in env_water:

  #Generate prompt
  prompt = "{} river".format(water)
  print(prompt)
  word_lists.append(get_blip(model, processor, results_folder,prompt))

for flow in env_flow:

  #Generate prompt
  prompt = "{} river".format(flow)
  print(prompt)
  word_lists.append(get_blip(model, processor, results_folder,prompt))

for weather in env_weather:

  #Generate prompt
  prompt = "{} river".format(weather)
  print(prompt)
  word_lists.append(get_blip(model, processor, results_folder,prompt))

for season in env_season:

  #Generate prompt
  prompt = "{} river".format(season)
  print(prompt)
  word_lists.append(get_blip(model, processor, results_folder,prompt))
# Out:
# clay river
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/0.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/1.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/2.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/3.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/4.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/5.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/6.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/7.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/8.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/9.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/10.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/11.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/12.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/13.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/14.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/15.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/16.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/17.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/18.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/19.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/20.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/21.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/22.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/23.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/24.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/25.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/26.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/27.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/28.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/clay river/29.jpg
# Updating captions.csv file
# mud river
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/0.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/1.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/2.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/3.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/4.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/5.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/6.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/7.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/8.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/9.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/10.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/11.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/12.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/13.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/14.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/15.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/16.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/17.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/18.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/19.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/20.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/21.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/22.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/23.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/24.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/25.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/26.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/27.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/28.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/mud river/29.jpg
# Updating captions.csv file
# sand river
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/0.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/1.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/2.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/3.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/4.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/5.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/6.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/7.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/8.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/9.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/10.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/11.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/12.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/13.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/14.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/15.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/16.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/17.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/18.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/19.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/20.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/21.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/22.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/23.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/24.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/25.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/26.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/27.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/28.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/sand river/29.jpg
# Updating captions.csv file
# pebble river
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/0.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/1.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/2.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/3.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/4.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/5.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/6.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/7.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/8.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/9.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/10.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/11.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/12.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/13.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/14.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/15.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/16.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/17.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/18.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/19.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/20.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/21.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/22.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/23.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/24.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/25.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/26.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/27.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/28.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/pebble river/29.jpg
# Updating captions.csv file
# gravel river
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/0.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/1.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/2.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/3.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/4.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/5.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/6.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/7.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/8.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/9.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/10.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/11.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/12.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/13.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/14.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/15.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/16.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/17.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/18.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/19.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/20.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/21.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/22.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/23.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/24.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/25.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/26.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/27.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/28.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/gravel river/29.jpg
# Updating captions.csv file
# cobble river
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/0.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/1.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/2.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/3.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/4.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/5.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/6.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/7.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/8.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/9.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/10.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/11.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/12.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/13.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/14.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/15.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/16.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/17.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/18.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/19.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/20.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/21.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/22.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/23.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/24.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/25.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/26.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/27.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/28.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/cobble river/29.jpg
# Updating captions.csv file
# boulders river
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/0.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/1.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/2.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/3.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/4.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/5.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/6.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/7.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/8.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/9.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/10.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/11.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/12.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/13.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/14.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/15.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/16.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/17.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/18.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/19.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/20.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/21.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/22.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/23.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/24.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/25.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/26.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/27.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/28.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/boulders river/29.jpg
# Updating captions.csv file
# rock river
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/0.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/1.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/2.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/3.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/4.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/5.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/6.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/7.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/8.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/9.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/10.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/11.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/12.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/13.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/14.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/15.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/16.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/17.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/18.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/19.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/20.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/21.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/22.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/23.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/24.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/25.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/26.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/27.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/28.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/rock river/29.jpg
# Updating captions.csv file
# shale river
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/0.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/1.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/2.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/3.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/4.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/5.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/6.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/7.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/8.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/9.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/10.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/11.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/12.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/13.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/14.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/15.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/16.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/17.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/18.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/19.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/20.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/21.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/22.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/23.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/24.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/25.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/26.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/27.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/28.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/shale river/29.jpg
# Updating captions.csv file
# bedrock river
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/0.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/1.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/2.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/3.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/4.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/5.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/6.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/7.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/8.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/9.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/10.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/11.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/12.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/13.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/14.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/15.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/16.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/17.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/18.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/19.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/20.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/21.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/22.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/23.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/24.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/25.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/26.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/27.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/28.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/bedrock river/29.jpg
# Updating captions.csv file
# limestone river
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/0.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/1.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/2.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/3.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/4.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/5.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/6.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/7.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/8.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/9.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/10.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/11.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/12.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/13.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/14.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/15.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/16.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/17.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/18.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/19.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/20.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/21.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/22.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/23.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/24.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/25.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/26.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/27.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/28.jpg
# Caption already complete for  /content/drive/MyDrive/ControlNet-Experiment/Results2/limestone river/29.jpg
# Updating captions.csv file
# granite river
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1369: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# 0   a stream flows through a rocky valley
# 1   a river in the mountains
# 2   a stream in the forest
# 3   a river in the mountains
# 4   a river in the mountains
# 5   a river in the mountains
# 6   a river in the mountains
# 7   a river in the mountains
# 8   a stream in the mountains
# 9   a stream in the mountains
# 10   a river in the mountains
# 11   a river in the mountains
# 12   a river in the mountains
# 13   a river in the mountains
# 14   a stream in the woods
# 15   a river in the woods
# 16   a stream in the mountains
# 17   a stream in the mountains
# 18   a lake in the mountains
# 19   a stream in the forest
# 20   a river in the mountains
# 21   a river in the mountains
# 22   a river in the woods
# 23   a river in the mountains
# 24   a river in the mountains
# 25   the river in the mountains
# 26   a river in the mountains
# 27   a river in the fall
# 28   a river in the mountains
# 29   a stream in the mountains
# Updating captions.csv file
# '\n\nfor water in env_water:\n\n  #Generate prompt\n  prompt = "{} river".format(water)\n  print(prompt)\n  word_lists.append(get_blip(model, processor, results_folder,prompt))\n\nfor flow in env_flow:\n\n  #Generate prompt\n  prompt = "{} river".format(flow)\n  print(prompt)\n  word_lists.append(get_blip(model, processor, results_folder,prompt))\n\nfor weather in env_weather:\n\n  #Generate prompt\n  prompt = "{} river".format(weather)\n  print(prompt)\n  word_lists.append(get_blip(model, processor, results_folder,prompt))\n\nfor season in env_season:\n\n  #Generate prompt\n  prompt = "{} river".format(season)\n  print(prompt)\n  word_lists.append(get_blip(model, processor, results_folder,prompt))\n\n'

# %%
import pandas as pd
from collections import Counter
import re

def drop_words_from_list(original_list, words_to_drop):
    return list(filter(lambda word: word not in words_to_drop, original_list))

def get_most_common_words_per_category(df, category_column, text_column, n=10):

    #drop duplicate rows
    df = df.drop_duplicates()

    # Step 1: Group the DataFrame by the category column
    grouped_df = df.groupby(category_column)

    # Initialize an empty dictionary to store the most common words for each category
    most_common_words_per_category = {}

    for category, group in grouped_df:
        # Step 2a: Tokenize the text within each group into individual words
        words = []
        for text in group[text_column]:
            words.extend(re.findall(r'\b\w+\b', text.lower()))

        #Step 2b: Remove common words
        words_to_drop = ['the','in','it','by','at','is','and','a','of','on','with','that']
        words = drop_words_from_list(words,words_to_drop)

        # Step 3: Count the occurrences of each word within each group
        word_counts = Counter(words)

        # Step 4: Find the most common words for each group
        most_common_words = word_counts.most_common(n)
        print(category, most_common_words)

    '''

        # Store the most common words for the current category in the dictionary
        most_common_words_per_category[category] = most_common_words

    # Create a DataFrame from the dictionary, handling cases where a category has fewer unique words than n
    df_most_common = pd.DataFrame(most_common_words_per_category).fillna('').astype(str)

    # Rename the columns with rank suffixes (e.g., 'word_1', 'word_2', etc.)
    df_most_common.columns = [f"word_{i+1}" for i in range(n)]

    return df_most_common
    '''
    return None

# Example usage
df_file ="{}/captions.csv".format(results_folder)

data = pd.read_csv(df_file)

# Find the top 3 most common words for each category and output as a DataFrame
most_common_per_category_df = get_most_common_words_per_category(data, category_column='prompt', text_column='caption', n=20)
#print(most_common_per_category_df)
# Out:
# Amazon river [('amazon', 26), ('river', 24), ('rainforest', 16), ('jungle', 5), ('boat', 5), ('water', 3), ('trees', 3), ('background', 2), ('red', 2), ('lake', 1), ('mountains', 1), ('full', 1), ('tourists', 1), ('houseboat', 1), ('growing', 1), ('banks', 1), ('people', 1), ('traveling', 1), ('down', 1), ('runs', 1)]
# Colorado river [('canyon', 29), ('river', 24), ('grand', 24), ('colorado', 16), ('horseshoe', 4), ('desert', 3), ('green', 3), ('water', 3), ('rio', 2), ('national', 2), ('park', 2), ('canyons', 2), ('overlooks', 1), ('over', 1), ('lake', 1), ('area', 1), ('small', 1), ('boat', 1), ('middle', 1)]
# Columbia river [('mountains', 19), ('lake', 18), ('surrounded', 17), ('river', 10), ('trees', 10), ('columbia', 6), ('view', 4), ('from', 3), ('boat', 3), ('top', 2), ('mountain', 2), ('gorge', 1), ('middle', 1), ('valley', 1), ('autumn', 1), ('traveling', 1), ('down', 1), ('flowers', 1), ('water', 1), ('background', 1)]
# Congo river [('river', 19), ('amazon', 8), ('water', 7), ('boat', 5), ('elephants', 4), ('rainforest', 4), ('jungle', 4), ('middle', 3), ('swimming', 3), ('stream', 2), ('large', 2), ('man', 2), ('canoe', 2), ('pada', 2), ('pond', 1), ('forest', 1), ('crocodile', 1), ('dinosaur', 1), ('an', 1), ('elephant', 1)]
# Danube river [('river', 16), ('danube', 11), ('city', 9), ('lake', 8), ('mountains', 4), ('germany', 4), ('surrounded', 3), ('heidelberg', 3), ('trees', 3), ('budapest', 3), ('boat', 3), ('background', 3), ('heart', 2), ('prague', 2), ('cruise', 2), ('czech', 2), ('krka', 2), ('wuhrung', 1), ('bratislava', 1), ('ljubljana', 1)]
# Darling river [('river', 22), ('trees', 9), ('surrounded', 7), ('lake', 6), ('middle', 5), ('forest', 4), ('end', 4), ('murray', 3), ('water', 3), ('mountains', 2), ('trail', 2), ('near', 2), ('runs', 2), ('through', 2), ('road', 2), ('valley', 2), ('clear', 2), ('area', 2), ('beach', 2), ('green', 2)]
# Ganges river [('river', 24), ('boats', 10), ('people', 7), ('gangra', 7), ('india', 6), ('houses', 5), ('are', 4), ('banks', 4), ('gang', 3), ('city', 3), ('gathered', 2), ('varnagar', 2), ('bank', 2), ('boat', 2), ('mountains', 1), ('group', 1), ('swimming', 1), ('ocean', 1), ('sitting', 1), ('vargarh', 1)]
# Hudson river [('skyline', 15), ('ga', 14), ('city', 12), ('river', 11), ('lake', 8), ('hudson', 6), ('view', 6), ('from', 6), ('background', 6), ('chicago', 4), ('top', 4), ('pittsburgh', 3), ('rock', 3), ('boston', 3), ('massachusetts', 3), ('fall', 3), ('trees', 3), ('boat', 3), ('sunset', 2), ('fore', 2)]
# Magdalena river [('river', 27), ('amazon', 9), ('jungle', 7), ('rainforest', 4), ('canoe', 4), ('through', 4), ('middle', 4), ('man', 4), ('water', 3), ('forest', 3), ('small', 3), ('mountains', 2), ('aerial', 2), ('view', 2), ('running', 2), ('runs', 2), ('rio', 2), ('valley', 2), ('trees', 1), ('two', 1)]
# Mekong river [('river', 30), ('boat', 13), ('mekong', 7), ('boats', 7), ('jungle', 6), ('amazon', 4), ('middle', 3), ('houses', 2), ('through', 2), ('long', 1), ('rainforest', 1), ('trees', 1), ('background', 1), ('houseboat', 1), ('several', 1), ('brazil', 1), ('two', 1), ('laos', 1), ('runs', 1), ('traveling', 1)]
# Mississippi river [('river', 17), ('trees', 13), ('baton', 8), ('lake', 7), ('surrounded', 7), ('bridge', 4), ('water', 3), ('runs', 3), ('through', 3), ('city', 3), ('background', 3), ('mountains', 2), ('brown', 2), ('golf', 2), ('course', 2), ('forest', 2), ('beach', 2), ('from', 2), ('tree', 2), ('sand', 1)]
# Murray river [('river', 25), ('trees', 12), ('murray', 10), ('water', 7), ('lake', 6), ('surrounded', 6), ('middle', 4), ('background', 3), ('near', 3), ('entrance', 3), ('to', 3), ('boat', 3), ('grass', 3), ('forest', 2), ('end', 2), ('road', 2), ('mouth', 2), ('brown', 1), ('red', 1), ('bush', 1)]
# Niger river [('river', 23), ('runs', 7), ('through', 7), ('amazon', 6), ('city', 5), ('water', 4), ('middle', 4), ('brazil', 4), ('trees', 3), ('rainforest', 2), ('aerial', 2), ('view', 2), ('forest', 2), ('background', 2), ('lake', 2), ('surrounded', 2), ('mountains', 1), ('rocks', 1), ('town', 1), ('abu', 1)]
# Nile river [('river', 22), ('city', 9), ('nile', 7), ('amazon', 5), ('lake', 4), ('egypt', 4), ('cairo', 4), ('mountains', 3), ('brazil', 3), ('desert', 3), ('runs', 2), ('through', 2), ('boat', 2), ('surrounded', 2), ('trees', 2), ('many', 1), ('boats', 1), ('jaigarh', 1), ('udar', 1), ('rajasthan', 1)]
# Paraguay river [('river', 25), ('amazon', 12), ('trees', 6), ('rainforest', 5), ('jungle', 5), ('water', 5), ('middle', 4), ('lake', 4), ('man', 2), ('canoe', 2), ('brazil', 2), ('boat', 2), ('brown', 2), ('forest', 2), ('surrounded', 2), ('view', 2), ('from', 2), ('background', 1), ('full', 1), ('tourists', 1)]
# Rhine river [('river', 31), ('boat', 9), ('germany', 7), ('rhine', 7), ('cruise', 3), ('bridge', 3), ('traveling', 3), ('large', 2), ('distance', 2), ('heidelberg', 2), ('background', 2), ('small', 2), ('town', 2), ('side', 2), ('down', 2), ('train', 2), ('along', 2), ('mountains', 2), ('yellow', 1), ('barge', 1)]
# Rio Negro river [('river', 25), ('amazon', 10), ('jungle', 8), ('rainforest', 6), ('rio', 4), ('brazil', 4), ('mountains', 3), ('view', 3), ('from', 3), ('top', 3), ('middle', 3), ('people', 2), ('mountain', 2), ('forest', 2), ('large', 1), ('crowd', 1), ('banks', 1), ('small', 1), ('group', 1), ('red', 1)]
# Seine river [('river', 29), ('paris', 16), ('seine', 13), ('boat', 5), ('bridge', 4), ('cruise', 3), ('city', 3), ('danube', 2), ('trees', 2), ('along', 2), ('over', 1), ('train', 1), ('canal', 1), ('lining', 1), ('sides', 1), ('rhine', 1), ('man', 1), ('kay', 1), ('traveling', 1), ('down', 1)]
# Sepik river [('river', 18), ('amazon', 10), ('rainforest', 8), ('jungle', 6), ('trees', 5), ('people', 4), ('middle', 4), ('group', 4), ('canoe', 3), ('water', 3), ('aerial', 3), ('view', 3), ('field', 2), ('lake', 2), ('boat', 2), ('background', 2), ('men', 2), ('through', 2), ('two', 1), ('children', 1)]
# Thames river [('river', 29), ('boat', 11), ('trees', 7), ('traveling', 5), ('down', 5), ('city', 4), ('background', 3), ('paris', 3), ('water', 2), ('thames', 2), ('london', 2), ('forest', 2), ('boats', 2), ('skyline', 2), ('bridge', 2), ('lake', 1), ('grass', 1), ('buildings', 1), ('park', 1), ('brown', 1)]
# Waikato river [('wai', 82), ('valley', 28), ('river', 21), ('boat', 7), ('lake', 6), ('green', 5), ('surrounded', 4), ('through', 4), ('lush', 4), ('middle', 4), ('from', 3), ('trees', 3), ('water', 3), ('travels', 3), ('top', 2), ('hill', 2), ('running', 2), ('raft', 2), ('down', 2), ('speed', 2)]
# Yamuna river [('river', 20), ('city', 14), ('front', 5), ('boat', 4), ('palace', 3), ('water', 3), ('large', 2), ('people', 2), ('golden', 2), ('dome', 2), ('fatehph', 2), ('mahal', 2), ('kolkata', 2), ('india', 2), ('new', 2), ('runs', 1), ('through', 1), ('yangyangn', 1), ('china', 1), ('temple', 1)]
# Yangtze river [('river', 25), ('yang', 21), ('china', 14), ('halo', 13), ('boat', 6), ('mountains', 5), ('traveling', 4), ('boats', 3), ('large', 3), ('down', 3), ('small', 2), ('middle', 2), ('through', 2), ('background', 2), ('surrounded', 2), ('city', 2), ('town', 1), ('filled', 1), ('train', 1), ('going', 1)]
# Zambezi river [('river', 25), ('water', 10), ('trees', 7), ('middle', 6), ('jungle', 4), ('background', 4), ('boat', 4), ('elephant', 2), ('forest', 2), ('tree', 2), ('amazon', 2), ('runs', 2), ('through', 2), ('people', 1), ('boats', 1), ('an', 1), ('standing', 1), ('near', 1), ('rainforest', 1), ('houseboat', 1)]
# autumn river [('river', 24), ('fall', 21), ('surrounded', 18), ('trees', 17), ('colors', 8), ('stream', 6), ('woods', 4), ('autumn', 3), ('leaves', 3), ('foliage', 2), ('colorful', 2), ('forest', 1), ('red', 1), ('mountains', 1)]
# bedrock river [('stream', 17), ('mountains', 12), ('river', 12), ('woods', 8), ('forest', 5), ('jungle', 2), ('through', 2), ('game', 2), ('runs', 1), ('gorge', 1), ('s', 1), ('screens', 1), ('are', 1), ('all', 1), ('different', 1), ('but', 1), ('still', 1), ('use', 1), ('running', 1), ('rocky', 1)]
# blue river [('river', 29), ('mountains', 11), ('forest', 8), ('jungle', 6), ('through', 4), ('valley', 2), ('runs', 2), ('flowing', 2), ('green', 2), ('rainforest', 1), ('middle', 1), ('bridge', 1), ('surrounded', 1), ('poster', 1), ('advertising', 1), ('filled', 1), ('rocks', 1), ('stream', 1), ('blue', 1), ('water', 1)]
# boulders river [('river', 17), ('mountains', 15), ('stream', 13), ('forest', 8), ('through', 3), ('rocks', 3), ('woods', 3), ('fore', 2), ('running', 2), ('flowing', 1), ('filled', 1), ('jungle', 1), ('rocky', 1), ('area', 1), ('grass', 1)]
# brook [('stream', 10), ('forest', 5), ('garden', 5), ('flowers', 5), ('woods', 4), ('mountains', 3), ('black', 3), ('small', 2), ('purple', 2), ('flower', 2), ('red', 2), ('dress', 2), ('person', 2), ('green', 2), ('lawn', 2), ('game', 2), ('woman', 2), ('large', 2), ('grows', 1), ('rock', 1)]
# brown river [('river', 20), ('stream', 9), ('forest', 9), ('mountains', 5), ('valley', 4), ('woods', 4), ('jungle', 4), ('middle', 3), ('flowing', 3), ('through', 3), ('rocky', 2), ('rocks', 2), ('waterfall', 1), ('canyon', 1), ('trees', 1), ('background', 1), ('grass', 1), ('fore', 1), ('fall', 1)]
# calm river [('river', 28), ('mountains', 14), ('woods', 6), ('forest', 4), ('surrounded', 3), ('trees', 3), ('jungle', 3), ('middle', 2), ('bridge', 1), ('over', 1), ('cruise', 1), ('stream', 1), ('lake', 1)]
# canal [('canal', 25), ('city', 9), ('park', 5), ('middle', 5), ('river', 4), ('trees', 3), ('narrow', 3), ('bridge', 3), ('boat', 3), ('through', 2), ('background', 2), ('forest', 2), ('boats', 2), ('over', 2), ('water', 1), ('flowing', 1), ('running', 1), ('buildings', 1), ('leiden', 1), ('lush', 1)]
# canyon river [('river', 22), ('canyon', 17), ('mountains', 12), ('grand', 10), ('person', 8), ('through', 4), ('virgin', 4), ('stream', 3), ('green', 3), ('flowing', 3), ('zion', 3), ('rocky', 2), ('middle', 1), ('valley', 1), ('woods', 1), ('runs', 1), ('forest', 1), ('filled', 1), ('rocks', 1), ('water', 1)]
# city river [('river', 23), ('city', 10), ('bridge', 4), ('background', 4), ('melbourne', 4), ('through', 3), ('skyline', 3), ('canal', 3), ('running', 2), ('night', 2), ('middle', 2), ('downtown', 2), ('brisbane', 2), ('red', 2), ('trees', 2), ('park', 2), ('buildings', 2), ('boat', 2), ('travels', 2), ('down', 2)]
# clay river [('river', 21), ('woods', 10), ('forest', 8), ('through', 8), ('stream', 7), ('mountains', 6), ('running', 4), ('flowing', 3), ('lush', 3), ('green', 3), ('trees', 3), ('middle', 2), ('field', 2), ('rocks', 2), ('kimberley', 2), ('lake', 2), ('surrounded', 2), ('small', 1), ('aerial', 1), ('view', 1)]
# clear river [('river', 24), ('mountains', 9), ('forest', 7), ('stream', 5), ('woods', 4), ('jungle', 3), ('valley', 2), ('canyon', 1), ('surrounded', 1), ('trees', 1), ('running', 1), ('through', 1), ('rocky', 1), ('small', 1), ('waterfall', 1), ('blue', 1), ('hole', 1), ('kimberley', 1), ('mountain', 1), ('background', 1)]
# cloudy river [('river', 30), ('mountains', 14), ('jungle', 7), ('middle', 3), ('forest', 3), ('amazon', 2), ('rainforest', 2), ('trees', 2), ('brown', 1), ('water', 1), ('background', 1), ('rio', 1), ('bushes', 1), ('fore', 1), ('park', 1), ('rapids', 1), ('surrounded', 1), ('clouds', 1)]
# cobble river [('river', 22), ('woods', 9), ('forest', 8), ('mountains', 6), ('trees', 4), ('fall', 3), ('stream', 3), ('runs', 2), ('through', 2), ('surrounded', 2), ('middle', 2), ('road', 2), ('to', 2), ('forested', 1), ('red', 1), ('house', 1), ('rocky', 1), ('beach', 1), ('rocks', 1), ('background', 1)]
# creek [('stream', 28), ('forest', 16), ('woods', 8), ('small', 2), ('running', 2), ('through', 2), ('lush', 2), ('green', 2), ('valley', 2), ('waterfall', 1), ('moss', 1), ('covered', 1), ('rocks', 1), ('jungle', 1), ('landscape', 1), ('river', 1), ('trees', 1), ('rainforest', 1)]
# desert river [('wadi', 97), ('nam', 34), ('river', 18), ('desert', 17), ('wadis', 4), ('lake', 4), ('canyon', 4), ('through', 2), ('rio', 2), ('flowing', 1), ('rocky', 1), ('green', 1), ('water', 1), ('red', 1), ('sand', 1), ('card', 1), ('scene', 1), ('cactus', 1), ('trail', 1), ('middle', 1)]
# dirty river [('river', 17), ('stream', 9), ('woods', 6), ('mountains', 5), ('jungle', 4), ('water', 3), ('forest', 3), ('brown', 2), ('muddy', 2), ('through', 2), ('middle', 2), ('trees', 2), ('background', 2), ('ripple', 1), ('pond', 1), ('bunch', 1), ('grass', 1), ('flowing', 1), ('canyon', 1), ('aerial', 1)]
# ditch [('through', 15), ('path', 14), ('forest', 10), ('field', 9), ('garden', 5), ('stream', 5), ('middle', 5), ('green', 4), ('grass', 4), ('small', 3), ('park', 2), ('wall', 2), ('woods', 2), ('running', 2), ('dirt', 2), ('row', 2), ('sun', 1), ('shining', 1), ('over', 1), ('mountain', 1)]
# drought river [('river', 13), ('dry', 11), ('stream', 10), ('bed', 6), ('background', 6), ('rocks', 5), ('middle', 5), ('trees', 5), ('small', 5), ('water', 5), ('forest', 4), ('road', 3), ('woods', 3), ('cracked', 3), ('clear', 3), ('grass', 2), ('land', 2), ('desert', 2), ('mountains', 2), ('pond', 2)]
# dry river [('river', 17), ('mountains', 9), ('desert', 6), ('dry', 6), ('stream', 6), ('forest', 6), ('background', 4), ('through', 3), ('red', 2), ('water', 2), ('middle', 2), ('landscape', 2), ('large', 2), ('running', 2), ('poster', 2), ('bed', 2), ('sun', 1), ('shining', 1), ('over', 1), ('field', 1)]
# fall river [('trees', 14), ('fall', 12), ('lake', 12), ('surrounded', 10), ('foliage', 8), ('view', 6), ('river', 6), ('town', 5), ('leaves', 3), ('red', 3), ('small', 2), ('woods', 2), ('person', 2), ('water', 2), ('from', 2), ('top', 2), ('over', 2), ('colors', 2), ('house', 2), ('row', 2)]
# field river [('field', 16), ('river', 9), ('green', 8), ('stream', 6), ('flowers', 6), ('through', 5), ('middle', 5), ('running', 4), ('lush', 4), ('mountains', 4), ('valley', 3), ('background', 3), ('sign', 3), ('grass', 3), ('forest', 2), ('yellow', 2), ('says', 2), ('woods', 2), ('grassy', 2), ('small', 2)]
# flat river [('river', 22), ('woods', 6), ('trees', 5), ('mountains', 5), ('water', 4), ('surrounded', 4), ('lake', 3), ('background', 2), ('man', 2), ('through', 2), ('kayak', 2), ('stream', 2), ('forest', 2), ('mountain', 1), ('large', 1), ('amount', 1), ('kay', 1), ('kaying', 1), ('down', 1), ('aerial', 1)]
# flooding river [('flooded', 18), ('street', 13), ('middle', 12), ('river', 11), ('city', 6), ('forest', 6), ('water', 5), ('house', 5), ('brown', 3), ('surrounded', 3), ('trees', 2), ('road', 2), ('flood', 2), ('town', 2), ('person', 2), ('residential', 2), ('area', 2), ('suburb', 2), ('running', 1), ('through', 1)]
# flowing river [('river', 24), ('mountains', 13), ('forest', 8), ('stream', 6), ('valley', 3), ('woods', 3), ('green', 2), ('amazon', 1), ('brazil', 1), ('running', 1), ('through', 1), ('lush', 1), ('trees', 1), ('water', 1), ('middle', 1), ('fall', 1)]
# forest river [('stream', 22), ('forest', 22), ('river', 4), ('mountains', 3), ('waterfall', 2), ('black', 2), ('background', 2), ('white', 2), ('red', 2), ('flower', 2), ('woods', 2), ('small', 1), ('framed', 1), ('photo', 1), ('runs', 1), ('through', 1), ('rainforest', 1)]
# granite river [('mountains', 23), ('river', 20), ('stream', 9), ('woods', 3), ('forest', 2), ('flows', 1), ('through', 1), ('rocky', 1), ('valley', 1), ('lake', 1), ('fall', 1)]
# grass river [('field', 15), ('green', 14), ('stream', 12), ('through', 10), ('mountains', 9), ('running', 8), ('river', 7), ('grass', 5), ('background', 5), ('lush', 5), ('grassy', 3), ('valley', 3), ('lake', 2), ('rice', 2), ('runs', 2), ('par', 2), ('middle', 1), ('sun', 1), ('setting', 1), ('growing', 1)]
# gravel river [('river', 22), ('woods', 9), ('stream', 7), ('mountains', 7), ('through', 6), ('forest', 6), ('running', 4), ('valley', 3), ('rocky', 2), ('green', 2), ('grassy', 2), ('field', 2), ('trees', 2), ('runs', 1), ('middle', 1), ('bed', 1), ('rocks', 1), ('background', 1), ('flowing', 1), ('lush', 1)]
# high flow river [('river', 29), ('mountains', 9), ('through', 6), ('woods', 5), ('valley', 5), ('flowing', 4), ('jungle', 3), ('small', 3), ('wai', 2), ('middle', 2), ('trees', 2), ('rocky', 2), ('stream', 2), ('rapids', 2), ('forest', 2), ('gorge', 1), ('surrounded', 1), ('lush', 1), ('green', 1), ('countryside', 1)]
# large river [('river', 25), ('wai', 15), ('pad', 14), ('mountains', 11), ('jungle', 5), ('background', 3), ('middle', 3), ('man', 2), ('black', 2), ('white', 2), ('red', 2), ('flower', 2), ('rainforest', 2), ('through', 2), ('small', 2), ('for', 2), ('game', 2), ('fishing', 1), ('rio', 1), ('amazon', 1)]
# limestone river [('river', 29), ('jungle', 10), ('mountains', 8), ('middle', 6), ('valley', 6), ('wai', 6), ('forest', 5), ('blue', 3), ('small', 1), ('waterfall', 1), ('woods', 1), ('running', 1), ('through', 1), ('gorge', 1), ('island', 1), ('boat', 1), ('canyon', 1)]
# low flow river [('river', 21), ('stream', 9), ('forest', 8), ('mountains', 8), ('through', 6), ('woods', 6), ('valley', 4), ('runs', 4), ('small', 2), ('middle', 2), ('waterfall', 1), ('mountain', 1), ('running', 1), ('rocky', 1), ('gorge', 1), ('jungle', 1), ('fall', 1), ('flowing', 1), ('lush', 1), ('green', 1)]
# mountain river [('river', 24), ('mountains', 21), ('ban', 15), ('forest', 6), ('stream', 5), ('mountain', 2), ('valley', 1), ('flowing', 1), ('through', 1), ('lush', 1), ('green', 1), ('middle', 1), ('bow', 1), ('view', 1), ('lake', 1), ('rocks', 1), ('fore', 1)]
# mud river [('river', 19), ('water', 11), ('muddy', 10), ('nam', 10), ('middle', 6), ('large', 6), ('trees', 5), ('background', 4), ('field', 4), ('mud', 4), ('dead', 2), ('road', 2), ('forest', 2), ('salt', 2), ('flats', 2), ('green', 2), ('brown', 2), ('small', 2), ('amount', 2), ('seen', 2)]
# muddy river [('river', 20), ('brown', 10), ('water', 10), ('trees', 8), ('middle', 6), ('muddy', 6), ('forest', 5), ('background', 5), ('stream', 4), ('park', 3), ('jungle', 3), ('flooded', 2), ('running', 2), ('through', 2), ('small', 1), ('pond', 1), ('aerial', 1), ('view', 1), ('fields', 1), ('filled', 1)]
# murky river [('stream', 15), ('river', 15), ('woods', 8), ('forest', 8), ('jungle', 8), ('mountains', 4), ('muddy', 1), ('small', 1), ('running', 1), ('through', 1), ('rocky', 1), ('valley', 1), ('painting', 1), ('fall', 1)]
# narrow river [('river', 30), ('mountains', 14), ('canyon', 5), ('jungle', 3), ('through', 3), ('gorge', 3), ('green', 3), ('woods', 2), ('valley', 2), ('rio', 2), ('forest', 1), ('flowing', 1), ('rocky', 1), ('runs', 1), ('narrow', 1), ('running', 1), ('lush', 1), ('blue', 1), ('kimberley', 1), ('virgin', 1)]
# overcast river [('river', 28), ('mountains', 17), ('woods', 4), ('forest', 3), ('jungle', 2), ('middle', 2), ('surrounded', 1), ('trees', 1), ('small', 1), ('stream', 1), ('runs', 1), ('through', 1), ('rocky', 1), ('gorge', 1), ('mountain', 1), ('lake', 1), ('pink', 1), ('sky', 1), ('fall', 1), ('bridge', 1)]
# pebble river [('river', 14), ('stream', 13), ('rocks', 9), ('mountains', 8), ('through', 6), ('valley', 5), ('running', 5), ('trees', 4), ('woods', 4), ('rocky', 3), ('forest', 3), ('background', 3), ('green', 3), ('moss', 3), ('lush', 2), ('surrounded', 2), ('runs', 1), ('water', 1), ('shore', 1), ('lake', 1)]
# pool river [('pool', 32), ('waterfall', 10), ('patio', 9), ('deck', 8), ('hot', 7), ('tub', 7), ('backyard', 7), ('surrounded', 5), ('stone', 4), ('lush', 3), ('lawn', 3), ('gaze', 2), ('large', 2), ('swimming', 2), ('green', 2), ('brick', 2), ('lounge', 2), ('chairs', 2), ('fence', 2), ('area', 2)]
# rainy river [('river', 26), ('forest', 9), ('background', 6), ('middle', 5), ('trees', 5), ('mountains', 4), ('brown', 3), ('water', 3), ('jungle', 3), ('lake', 3), ('man', 2), ('red', 2), ('woods', 2), ('fishing', 1), ('park', 1), ('tent', 1), ('bank', 1), ('boat', 1), ('end', 1), ('road', 1)]
# rapids river [('river', 29), ('mountains', 19), ('forest', 5), ('woods', 3), ('rocks', 2), ('man', 1), ('raft', 1), ('rafting', 1), ('down', 1), ('jungle', 1), ('runs', 1), ('through', 1), ('filled', 1), ('water', 1), ('stream', 1)]
# riffle river [('river', 26), ('mountains', 13), ('woods', 6), ('stream', 4), ('jungle', 3), ('forest', 3), ('wai', 2), ('through', 2), ('rocky', 2), ('rocks', 2), ('valley', 1), ('runs', 1), ('gorge', 1), ('trees', 1), ('background', 1), ('few', 1), ('running', 1), ('area', 1)]
# river [('river', 27), ('mountains', 8), ('forest', 7), ('jungle', 5), ('woods', 3), ('red', 2), ('stream', 2), ('middle', 2), ('rio', 2), ('brown', 1), ('bear', 1), ('swimming', 1), ('water', 1), ('house', 1), ('banks', 1), ('running', 1), ('through', 1), ('lush', 1), ('green', 1), ('valley', 1)]
# river Alaska [('river', 28), ('mountains', 16), ('ban', 11), ('canadian', 7), ('rockies', 6), ('middle', 4), ('forest', 4), ('yukon', 3), ('trees', 3), ('background', 3), ('lake', 2), ('bow', 2), ('rapids', 1), ('whitewater', 1), ('surrounded', 1), ('wilderness', 1), ('view', 1), ('rocks', 1), ('fore', 1)]
# river Alberta [('river', 27), ('mountains', 18), ('ban', 15), ('forest', 5), ('trees', 3), ('middle', 2), ('through', 2), ('surrounded', 2), ('water', 2), ('woods', 2), ('small', 1), ('waterfall', 1), ('running', 1), ('brown', 1), ('background', 1), ('flowing', 1), ('filled', 1), ('rocks', 1), ('beautiful', 1), ('view', 1)]
# river Argentina [('river', 30), ('rio', 8), ('jungle', 6), ('middle', 6), ('mountains', 4), ('park', 4), ('through', 4), ('valley', 3), ('city', 2), ('raft', 2), ('running', 2), ('lush', 2), ('green', 2), ('forest', 2), ('rocks', 2), ('water', 2), ('trees', 2), ('national', 1), ('runs', 1), ('two', 1)]
# river Australia [('river', 25), ('trees', 8), ('blue', 7), ('surrounded', 6), ('end', 5), ('kimberley', 5), ('gorge', 4), ('murray', 4), ('lake', 4), ('near', 4), ('rocks', 3), ('water', 3), ('track', 2), ('runs', 2), ('through', 2), ('forest', 2), ('top', 2), ('boat', 2), ('entrance', 2), ('to', 2)]
# river Brazil [('river', 25), ('mountains', 8), ('jungle', 7), ('middle', 4), ('rio', 3), ('brazil', 3), ('green', 3), ('through', 3), ('amazon', 2), ('water', 2), ('rocks', 2), ('flowing', 2), ('canyon', 2), ('city', 2), ('valley', 1), ('pink', 1), ('shore', 1), ('blue', 1), ('lagoon', 1), ('view', 1)]
# river British Colubmia [('river', 28), ('trees', 7), ('woods', 6), ('middle', 4), ('forest', 4), ('background', 3), ('through', 3), ('end', 2), ('runs', 2), ('lush', 2), ('green', 2), ('landscape', 2), ('flowers', 2), ('bushes', 2), ('small', 1), ('pond', 1), ('rocks', 1), ('walk', 1), ('countryside', 1), ('brown', 1)]
# river British Columbia [('river', 26), ('mountains', 22), ('surrounded', 5), ('lake', 4), ('trees', 4), ('columbia', 3), ('middle', 1), ('forest', 1), ('view', 1), ('from', 1), ('top', 1), ('mountain', 1), ('wild', 1), ('flowers', 1), ('fore', 1), ('boat', 1), ('water', 1), ('woods', 1), ('bow', 1), ('canadian', 1)]
# river California [('river', 32), ('mountains', 18), ('rio', 7), ('canyon', 4), ('middle', 3), ('trees', 2), ('tree', 1), ('andes', 1), ('wai', 1), ('from', 1), ('top', 1), ('hill', 1), ('valley', 1), ('forest', 1), ('end', 1), ('trail', 1), ('rocks', 1), ('fore', 1), ('area', 1), ('lake', 1)]
# river Canada [('river', 27), ('mountains', 20), ('ban', 15), ('surrounded', 8), ('trees', 8), ('lake', 3), ('train', 1), ('travels', 1), ('along', 1), ('from', 1), ('top', 1), ('mountain', 1), ('wild', 1), ('flowers', 1), ('fore', 1), ('woods', 1), ('bow', 1), ('fall', 1)]
# river China [('river', 29), ('mountains', 14), ('boat', 6), ('boats', 4), ('middle', 3), ('yang', 3), ('traveling', 2), ('down', 2), ('several', 2), ('china', 2), ('long', 1), ('bridge', 1), ('over', 1), ('people', 1), ('amazon', 1), ('brazil', 1), ('houseboat', 1), ('map', 1), ('routes', 1), ('great', 1)]
# river Colorado [('river', 27), ('mountains', 21), ('through', 5), ('canyon', 4), ('flowing', 3), ('virgins', 2), ('trees', 2), ('rocks', 2), ('rocky', 2), ('surrounded', 1), ('bridge', 1), ('over', 1), ('forest', 1), ('filled', 1), ('valley', 1), ('stream', 1), ('woods', 1), ('flows', 1), ('waterfall', 1), ('green', 1)]
# river Florida [('river', 25), ('forest', 9), ('jungle', 8), ('middle', 7), ('trees', 7), ('surrounded', 5), ('stream', 5), ('through', 4), ('water', 3), ('runs', 3), ('park', 2), ('brown', 1), ('house', 1), ('banks', 1), ('flows', 1), ('land', 1), ('woods', 1), ('city', 1), ('canal', 1), ('bridge', 1)]
# river Georgia [('river', 26), ('woods', 10), ('mountains', 8), ('surrounded', 4), ('trees', 4), ('stream', 3), ('through', 3), ('valley', 2), ('bridge', 2), ('over', 2), ('forest', 2), ('runs', 1), ('background', 1), ('red', 1), ('house', 1), ('banks', 1), ('flowing', 1), ('rocky', 1), ('running', 1), ('lake', 1)]
# river Germany [('river', 30), ('mountains', 6), ('city', 5), ('forest', 5), ('trees', 4), ('bridge', 3), ('fall', 3), ('middle', 3), ('boats', 2), ('background', 2), ('flowing', 2), ('through', 2), ('surrounded', 2), ('valley', 1), ('house', 1), ('bank', 1), ('barge', 1), ('flowers', 1), ('fore', 1), ('grass', 1)]
# river Iceland [('river', 26), ('valley', 24), ('through', 20), ('flowing', 16), ('running', 5), ('green', 5), ('middle', 4), ('iceland', 3), ('small', 2), ('stream', 2), ('mountains', 1), ('long', 1), ('exposure', 1), ('over', 1), ('rocks', 1), ('lush', 1), ('rocky', 1), ('lake', 1), ('grassy', 1), ('plain', 1)]
# river India [('river', 25), ('jungle', 11), ('mountains', 6), ('map', 4), ('middle', 3), ('boat', 2), ('thatched', 1), ('roof', 1), ('beautiful', 1), ('city', 1), ('lahore', 1), ('elephants', 1), ('nile', 1), ('kingdom', 1), ('roman', 1), ('empire', 1), ('region', 1), ('cover', 1), ('book', 1), ('desert', 1)]
# river Iowa [('river', 30), ('trees', 14), ('surrounded', 6), ('water', 4), ('middle', 4), ('through', 4), ('park', 3), ('runs', 3), ('boat', 3), ('background', 2), ('forest', 2), ('travels', 2), ('along', 2), ('bridge', 2), ('town', 2), ('lake', 1), ('mountains', 1), ('from', 1), ('above', 1), ('brown', 1)]
# river Kentucky [('river', 29), ('trees', 8), ('woods', 8), ('surrounded', 5), ('brown', 2), ('water', 2), ('background', 2), ('fall', 2), ('mountains', 2), ('forest', 2), ('rapids', 2), ('boat', 2), ('travels', 2), ('down', 2), ('middle', 2), ('red', 1), ('house', 1), ('banks', 1), ('jungle', 1), ('end', 1)]
# river Louisiana [('river', 31), ('trees', 11), ('middle', 9), ('forest', 5), ('water', 4), ('park', 4), ('surrounded', 3), ('through', 3), ('end', 2), ('trail', 2), ('jungle', 2), ('bridge', 2), ('over', 2), ('runs', 2), ('moss', 2), ('growing', 2), ('banks', 2), ('amazon', 2), ('rocks', 1), ('background', 1)]
# river Maine [('river', 27), ('woods', 10), ('trees', 8), ('mountains', 5), ('surrounded', 5), ('fall', 3), ('rocks', 3), ('water', 2), ('background', 2), ('forest', 2), ('red', 2), ('stream', 2), ('brown', 1), ('middle', 1), ('bridge', 1), ('over', 1), ('house', 1), ('banks', 1), ('sign', 1), ('says', 1)]
# river Montana [('river', 27), ('mountains', 23), ('ban', 15), ('through', 2), ('forest', 2), ('background', 2), ('columbia', 2), ('running', 1), ('middle', 1), ('boat', 1), ('travels', 1), ('down', 1), ('rocks', 1), ('fore', 1), ('stream', 1), ('flowing', 1), ('canyon', 1), ('lake', 1), ('trees', 1), ('waterfall', 1)]
# river New York [('skyline', 13), ('river', 13), ('city', 10), ('new', 9), ('york', 9), ('background', 7), ('chicago', 5), ('buildings', 5), ('building', 4), ('bridge', 3), ('night', 3), ('manhattan', 3), ('from', 3), ('boats', 3), ('ny', 2), ('view', 2), ('top', 2), ('empire', 2), ('sears', 2), ('over', 2)]
# river New Zealand [('river', 28), ('valley', 18), ('wai', 17), ('middle', 7), ('through', 5), ('new', 4), ('zealand', 4), ('mountains', 4), ('lush', 3), ('green', 3), ('blue', 2), ('running', 2), ('flowing', 2), ('forest', 2), ('lake', 2), ('runs', 1), ('gorge', 1)]
# river Nigeria [('river', 27), ('jungle', 10), ('boat', 7), ('through', 5), ('amazon', 3), ('middle', 3), ('runs', 3), ('brazil', 2), ('village', 2), ('green', 2), ('rocks', 1), ('water', 1), ('aerial', 1), ('view', 1), ('full', 1), ('people', 1), ('forest', 1), ('mountains', 1), ('town', 1), ('field', 1)]
# river North Carolina [('river', 18), ('city', 8), ('woods', 7), ('downtown', 5), ('through', 4), ('from', 4), ('skyline', 4), ('stream', 4), ('runs', 3), ('forest', 3), ('view', 3), ('nashville', 2), ('tn', 2), ('bridge', 2), ('top', 1), ('hill', 1), ('overlooking', 1), ('beach', 1), ('middle', 1), ('sign', 1)]
# river Ontario [('river', 27), ('trees', 11), ('surrounded', 8), ('woods', 6), ('rocks', 4), ('background', 3), ('middle', 3), ('boat', 3), ('from', 2), ('fall', 2), ('water', 2), ('bridge', 1), ('shore', 1), ('house', 1), ('top', 1), ('rock', 1), ('flowers', 1), ('fore', 1), ('runs', 1), ('through', 1)]
# river Peru [('river', 28), ('mountains', 15), ('jungle', 5), ('rio', 3), ('andes', 3), ('people', 2), ('dirt', 1), ('road', 1), ('leading', 1), ('to', 1), ('valley', 1), ('two', 1), ('canoe', 1), ('filled', 1), ('runs', 1), ('through', 1), ('lake', 1), ('boat', 1), ('view', 1), ('from', 1)]
# river Quebec [('river', 27), ('trees', 9), ('mountains', 8), ('surrounded', 7), ('fall', 3), ('bridge', 3), ('lake', 3), ('gorge', 2), ('over', 2), ('autumn', 2), ('woods', 2), ('chateau', 2), ('middle', 1), ('forest', 1), ('water', 1), ('red', 1), ('houses', 1), ('boats', 1), ('boat', 1), ('travels', 1)]
# river Russia [('river', 27), ('surrounded', 11), ('trees', 9), ('mountains', 7), ('through', 4), ('forest', 4), ('woods', 4), ('runs', 3), ('middle', 3), ('city', 2), ('lake', 2), ('fall', 2), ('gorge', 1), ('yellow', 1), ('leaves', 1), ('train', 1), ('traveling', 1), ('valley', 1), ('aerial', 1), ('view', 1)]
# river Scotland [('river', 28), ('through', 10), ('mountains', 9), ('running', 8), ('valley', 7), ('lush', 7), ('green', 7), ('countryside', 6), ('forest', 5), ('scottish', 4), ('flowing', 2), ('stream', 2), ('woods', 2), ('surrounded', 1), ('bridge', 1), ('over', 1), ('highlands', 1), ('yorkshire', 1), ('rocks', 1), ('trees', 1)]
# river South Africa [('river', 30), ('kimberley', 16), ('middle', 9), ('mountains', 7), ('rocks', 5), ('rocky', 3), ('valley', 3), ('water', 3), ('trees', 3), ('gorge', 2), ('view', 2), ('fore', 2), ('flowing', 2), ('through', 2), ('rio', 2), ('man', 1), ('canoe', 1), ('desert', 1), ('wilderness', 1), ('aerial', 1)]
# river Texas [('river', 30), ('trees', 14), ('woods', 6), ('water', 5), ('background', 4), ('forest', 4), ('surrounded', 3), ('rocks', 3), ('runs', 2), ('through', 2), ('fore', 2), ('rapids', 2), ('middle', 2), ('rio', 2), ('brown', 1), ('dirt', 1), ('road', 1), ('clouds', 1), ('bridge', 1), ('over', 1)]
# river USA [('river', 22), ('flag', 7), ('boat', 6), ('water', 4), ('trees', 4), ('american', 4), ('mountains', 3), ('background', 3), ('flying', 3), ('over', 3), ('for', 2), ('rio', 2), ('surrounded', 2), ('raft', 2), ('red', 2), ('rocks', 2), ('an', 2), ('logo', 2), ('rapids', 2), ('col', 2)]
# river Vermont [('river', 27), ('mountains', 15), ('woods', 7), ('fall', 4), ('stream', 3), ('surrounded', 3), ('trees', 3), ('red', 1), ('house', 1), ('banks', 1), ('small', 1), ('waterfall', 1), ('middle', 1), ('adis', 1)]
# river Washington [('river', 28), ('trees', 10), ('surrounded', 8), ('woods', 7), ('mountains', 3), ('forest', 3), ('boat', 3), ('from', 2), ('water', 2), ('above', 1), ('bridge', 1), ('middle', 1), ('house', 1), ('banks', 1), ('end', 1), ('trail', 1), ('stream', 1), ('grass', 1), ('fore', 1), ('blue', 1)]
# river Zimbabwe [('river', 30), ('jungle', 11), ('middle', 8), ('water', 4), ('brown', 3), ('trees', 3), ('rio', 3), ('rocks', 3), ('forest', 2), ('rapids', 2), ('park', 2), ('small', 1), ('lake', 1), ('background', 1), ('runs', 1), ('through', 1), ('canyon', 1), ('amazon', 1), ('rainforest', 1), ('boat', 1)]
# rock river [('river', 23), ('trees', 8), ('woods', 7), ('surrounded', 5), ('rocks', 5), ('through', 4), ('forest', 4), ('lake', 4), ('mountains', 3), ('middle', 3), ('stream', 2), ('rocky', 2), ('fall', 2), ('background', 2), ('runs', 2), ('water', 2), ('gorge', 2), ('flows', 1), ('valley', 1), ('rio', 1)]
# rural river [('river', 26), ('mountains', 8), ('through', 7), ('running', 6), ('jungle', 6), ('green', 6), ('lush', 5), ('valley', 5), ('stream', 4), ('woods', 3), ('countryside', 2), ('dirt', 1), ('road', 1), ('red', 1), ('barn', 1), ('sits', 1), ('bank', 1), ('man', 1), ('kayak', 1), ('paddles', 1)]
# sand river [('sand', 24), ('desert', 10), ('dunes', 9), ('for', 7), ('sahara', 6), ('sign', 6), ('river', 5), ('logo', 4), ('dune', 4), ('beach', 3), ('game', 3), ('says', 3), ('blue', 2), ('nam', 2), ('middle', 2), ('timer', 2), ('surfs', 1), ('sky', 1), ('title', 1), ('sad', 1)]
# shale river [('river', 23), ('woods', 13), ('mountains', 11), ('stream', 6), ('fall', 3), ('through', 2), ('surrounded', 1), ('trees', 1), ('flowing', 1), ('rocky', 1), ('valley', 1), ('runs', 1), ('forest', 1), ('beautiful', 1), ('sunset', 1), ('over', 1), ('lake', 1), ('autumn', 1)]
# small river [('river', 19), ('stream', 11), ('woods', 9), ('forest', 8), ('mountains', 4), ('canyon', 2), ('jungle', 2), ('through', 2), ('surrounded', 1), ('trees', 1), ('house', 1), ('runs', 1), ('rocky', 1), ('gorge', 1), ('small', 1), ('middle', 1), ('end', 1), ('trail', 1), ('running', 1), ('lush', 1)]
# snowy river [('river', 18), ('mountains', 15), ('snow', 14), ('covered', 11), ('snowy', 7), ('woods', 6), ('stream', 5), ('trees', 3), ('winter', 3), ('through', 2), ('horses', 2), ('scene', 2), ('forest', 2), ('flows', 1), ('valley', 1), ('grazing', 1), ('landscape', 1), ('ground', 1), ('path', 1), ('beautiful', 1)]
# spring river [('river', 20), ('woods', 10), ('flowers', 8), ('stream', 7), ('pink', 7), ('mountains', 6), ('fore', 4), ('forest', 3), ('trees', 2), ('middle', 2), ('field', 2), ('lake', 2), ('surrounded', 1), ('green', 1), ('tulipis', 1), ('purple', 1), ('framed', 1), ('print', 1), ('cherry', 1), ('tree', 1)]
# steep river [('river', 23), ('mountains', 14), ('forest', 11), ('stream', 5), ('through', 3), ('valley', 2), ('jungle', 2), ('train', 1), ('travels', 1), ('flowing', 1), ('lush', 1), ('green', 1), ('runs', 1), ('rocky', 1), ('gorge', 1), ('sun', 1), ('shining', 1), ('over', 1), ('rapids', 1), ('kicking', 1)]
# stream [('stream', 16), ('forest', 14), ('woods', 4), ('waterfall', 4), ('small', 4), ('middle', 3), ('river', 3), ('jungle', 2), ('pink', 2), ('stone', 2), ('patio', 2), ('mountains', 2), ('background', 2), ('running', 1), ('through', 1), ('lush', 1), ('green', 1), ('valley', 1), ('flowers', 1), ('water', 1)]
# summer river [('river', 25), ('mountains', 8), ('flowers', 5), ('forest', 5), ('jungle', 5), ('rocks', 3), ('woods', 3), ('stream', 2), ('fore', 2), ('beautiful', 2), ('middle', 2), ('garden', 1), ('ocean', 1), ('wallpaper', 1), ('red', 1), ('tent', 1), ('bank', 1), ('along', 1), ('framed', 1), ('print', 1)]
# sunny river [('river', 30), ('woods', 8), ('forest', 7), ('middle', 6), ('over', 3), ('mountains', 2), ('through', 2), ('rocks', 2), ('jungle', 2), ('sun', 2), ('shining', 2), ('trees', 2), ('runs', 1), ('valley', 1), ('red', 1), ('house', 1), ('banks', 1), ('water', 1), ('grass', 1), ('fore', 1)]
# swamp river [('tar', 18), ('river', 17), ('stream', 10), ('forest', 10), ('jungle', 8), ('woods', 5), ('middle', 4), ('aerial', 2), ('view', 2), ('rainforest', 2), ('small', 2), ('game', 2), ('mountains', 1), ('flowing', 1), ('through', 1), ('forested', 1), ('wooden', 1), ('boardwalk', 1), ('leads', 1), ('to', 1)]
# tannic river [('river', 19), ('mountains', 7), ('lake', 6), ('trees', 6), ('water', 5), ('surrounded', 5), ('middle', 4), ('forest', 4), ('red', 3), ('jungle', 3), ('small', 2), ('an', 2), ('boat', 2), ('rocky', 1), ('shore', 1), ('pond', 1), ('valley', 1), ('rio', 1), ('amazon', 1), ('brazil', 1)]
# tidal river [('river', 11), ('trees', 8), ('beach', 7), ('rocks', 6), ('mountains', 5), ('small', 4), ('lake', 4), ('through', 4), ('water', 4), ('rocky', 3), ('background', 3), ('island', 3), ('surrounded', 3), ('runs', 2), ('valley', 2), ('shore', 2), ('green', 2), ('middle', 2), ('rainforest', 2), ('end', 2)]
# urban river [('river', 22), ('city', 14), ('through', 7), ('canal', 3), ('forest', 3), ('running', 3), ('runs', 3), ('woods', 3), ('melbourne', 3), ('middle', 2), ('stream', 2), ('pond', 1), ('ripple', 1), ('marks', 1), ('downtown', 1), ('center', 1), ('skyline', 1), ('night', 1), ('kuala', 1), ('malaysia', 1)]
# valley river [('river', 24), ('mountains', 20), ('stream', 7), ('valley', 7), ('wai', 6), ('forest', 5), ('rio', 2), ('mountain', 1), ('flowing', 1), ('through', 1), ('lush', 1), ('green', 1), ('woods', 1), ('canyon', 1)]
# waterfall river [('waterfall', 19), ('forest', 12), ('jungle', 10), ('small', 8), ('river', 6), ('stream', 5), ('middle', 4), ('woods', 3), ('mountains', 2), ('rainforest', 2), ('green', 1), ('valley', 1)]
# whitewater river [('river', 29), ('mountains', 24), ('forest', 2), ('valley', 2), ('woods', 2), ('stream', 1)]
# wide river [('river', 23), ('mountains', 13), ('green', 3), ('over', 3), ('jungle', 3), ('water', 2), ('lake', 2), ('running', 2), ('through', 2), ('lush', 2), ('forest', 2), ('view', 2), ('mountain', 2), ('amazon', 2), ('brown', 1), ('trees', 1), ('surrounded', 1), ('forests', 1), ('gorge', 1), ('aerial', 1)]
# winter river [('river', 23), ('winter', 12), ('snow', 11), ('covered', 7), ('mountains', 6), ('woods', 5), ('snowy', 4), ('stream', 4), ('trees', 4), ('landscape', 2), ('middle', 2), ('forest', 2), ('ground', 1), ('scene', 1), ('lake', 1)]
